# %% [markdown]
# # Analyzing Political Discourse in the 2024 U.S. Presidential Election
# ### Sentiment Analysis (VADER) and Topic Modeling (LDA) on Twitter Data
# ## Project Overview
#
# This project examines political discourse surrounding the **2024 U.S. Presidential Election** using a large corpus of Twitter data.
# The analysis combines:
#
# - **Sentiment Analysis** using VADER
# - **Topic Modeling** using Latent Dirichlet Allocation (LDA)
#
# The goal is to understand:
#
# - How sentiment is distributed across candidates
# - Where political negativity and positivity concentrate
# - How discussion volume interacts with sentiment
# - How sentiment varies across discourse themes

# %% [markdown]
# ## 1. Dataset Description
#
# The raw dataset consists of tweet-level data collected from Twitter and includes:
#
# - Tweet text
# - User identifiers
# - Engagement metrics (likes, quotes)
# - Timestamp information stored in epoch format
#
# Due to dataset size and redistribution constraints, only preprocessing logic and
# derived datasets are included in this repository.

# %%
import pandas as pd
import numpy as np
import re
import spacy

# %% [markdown]
# ## 2. Data Loading and Initial Processing
#
# The dataset is loaded from a CSV file.
# Timestamp information is converted from epoch format to a human-readable datetime format.
# Only columns required for textual analysis and engagement-based interpretation are retained.

# %%
df=pd.read_csv('november_chunk_1.csv')

# %%
# Convert 'epoch' column to datetime
df['date'] = pd.to_datetime(df['epoch'], unit='s')

# %%
# Drop the old 'epoch' column if not needed
df.drop(columns=['epoch'], inplace=True)

# %%
df.head()
# Out:
#     0    type            id     username  \
# 0 NaN  tweet-  1.859386e+18  SATraveler2
# 1 NaN  tweet-  1.859386e+18   JoeZumwalt
# 2 NaN  tweet-  1.859386e+18    67sharona
# 3 NaN  tweet-  1.859386e+18  TruthAboutF
# 4 NaN  tweet-  1.859386e+18  Hump98Clint
#
#                                                 text  \
# 0  @MdBreathe continued-  \nto develop a techniqu...
# 1  @UROCKlive1 all these banderite/nazi sycophant...
# 2  Laken Rileys Death Would Of Never Ever Happene...
# 3  POV: you go downstairs in the middle of the ni...
# 4  @mtgreenee This is a good question, are you no...
#
#                                                  url  \
# 0  https://twitter.com/SATraveler2/status/1859386...
# 1  https://twitter.com/JoeZumwalt/status/18593862...
# 2  https://twitter.com/67sharona/status/185938622...
# 3  https://twitter.com/TruthAboutF/status/1859386...
# 4  https://twitter.com/Hump98Clint/status/1859386...
#
#                                                media  retweetedTweet  \
# 0                                                 []           False
# 1                                                 []           False
# 2                                                 []           False
# 3  [{'display_url': 'pic.x.com/tUK0JjrAHY', 'expa...           False
# 4                                                 []           False
#
#    retweetedTweetID  retweetedUserID  ...  \
# 0               NaN              NaN  ...
# 1               NaN              NaN  ...
# 2               NaN              NaN  ...
# 3               NaN              NaN  ...
# 4               NaN              NaN  ...
#
#                                                links  \
# 0  [{'display_url': 'childrenshealthdefense.org/d...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                         viewCount quotedTweet  \
# 0     {'count': '4', 'state': 'EnabledWithCount'}       False
# 1     {'count': '3', 'state': 'EnabledWithCount'}       False
# 2    {'count': '25', 'state': 'EnabledWithCount'}       False
# 3  {'count': '1476', 'state': 'EnabledWithCount'}       False
# 4     {'count': '8', 'state': 'EnabledWithCount'}       False
#
#    in_reply_to_screen_name  in_reply_to_status_id_str  \
# 0                MdBreathe               1.859234e+18
# 1               UROCKlive1               1.859057e+18
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                mtgreenee               1.859042e+18
#
#    in_reply_to_user_id_str  location  cash_app_handle  \
# 0             1.139217e+18       NaN              NaN
# 1             8.798304e+07       NaN              NaN
# 2                      NaN       NaN              NaN
# 3                      NaN       NaN              NaN
# 4             8.260652e+17       NaN              NaN
#
#                                                 user                date
# 0  {'id': 1280313070053502978, 'id_str': '1280313... 2024-11-20 23:59:59
# 1  {'id': 1087502843102162945, 'id_str': '1087502... 2024-11-20 23:59:57
# 2  {'id': 792933462256652288, 'id_str': '79293346... 2024-11-20 23:59:56
# 3  {'id': 1424726838144901122, 'id_str': '1424726... 2024-11-20 23:59:55
# 4  {'id': 1942063262, 'id_str': '1942063262', 'ur... 2024-11-20 23:59:53
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 3. Feature Selection
#
# To maintain analytical focus and reduce noise, the following features are retained:
#
# - `username`: anonymized user reference
# - `text`: raw tweet content
# - `likeCount`, `quoteCount`: engagement indicators
# - `date`: posting timestamp
#
# All other metadata fields are excluded from further analysis.

# %%
# Retain only columns relevant for NLP analysis and engagement metadata
required_columns = [
    'username', 'text', 'likeCount', 'quoteCount', 'epoch'
]

df = df[required_columns].copy()

# %%
df.head(10)
# Out:
#           username                                               text  \
# 0      SATraveler2  @MdBreathe continued-  \nto develop a techniqu...
# 1       JoeZumwalt  @UROCKlive1 all these banderite/nazi sycophant...
# 2        67sharona  Laken Rileys Death Would Of Never Ever Happene...
# 3      TruthAboutF  POV: you go downstairs in the middle of the ni...
# 4      Hump98Clint  @mtgreenee This is a good question, are you no...
# 5      BlakeBurman  The race is on for the next DNC chair. Martin ...
# 6  Chip_quicksteps  @DefiyantlyFree Kamala Harris is a leech grift...
# 7  Cynthia19941119  @BarronTrumpoo Kamala Harris is Vice President...
# 8        G2638Garr  @MayorOfLA @POTUS A Pew study this year fall s...
# 9     mascotmike12           @TheDemocrats Wtf are you doing Montana?
#
#    likeCount  quoteCount                date
# 0        0.0         0.0 2024-11-20 23:59:59
# 1        0.0         0.0 2024-11-20 23:59:57
# 2        1.0         0.0 2024-11-20 23:59:56
# 3       14.0         0.0 2024-11-20 23:59:55
# 4        1.0         0.0 2024-11-20 23:59:53
# 5        3.0         1.0 2024-11-20 23:59:51
# 6        0.0         0.0 2024-11-20 23:59:50
# 7        0.0         0.0 2024-11-20 23:59:49
# 8        0.0         0.0 2024-11-20 23:59:49
# 9        7.0         0.0 2024-11-20 23:59:45

# %%
df.shape
# Out:
# (50000, 5)

# %%
# Save to CSV without the index
df_new.to_csv('election.csv', index=False)

print("✅ New dataset saved as 'election.csv' successfully!")
# Out:
# ✅ New dataset saved as 'election.csv' successfully!

# %% [markdown]
# ## 5. Output Files
#
# The following processed datasets are generated:
#
# - `election.csv`
#   Contains cleaned metadata and raw tweet text.
#
# These outputs are used as inputs for subsequent sentiment analysis and topic modeling notebooks.
